# %% [markdown]
# <a href="https://colab.research.google.com/github/junghoum/Hello-world/blob/main/n121-hypothesis-test/n121a-hypothesis-test.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src='https://i.imgur.com/RDAD11M.png' width = '200' align = 'right'>
#
# ## *DATA SCIENCE / SECTION 1 / SPRINT 2 / NOTE 1*
#
# # 📝 Assignment

# %% [markdown]
# # 가설 검정

# %% [markdown]
# ## 1. One-Sample T-test 연습

# %% [markdown]
# ### 데이터 불러오기
# - [서울시 가로수 데이터셋](https://data.seoul.go.kr/dataList/367/S/2/datasetView.do)을 사용합니다.
#
# 다음 링크를 참조하세요.
# <https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/seoul_tree/seoul_tree.txt>

# %%
import pandas as pd
import numpy as np

url = 'https://ds-lecture-data.s3.ap-northeast-2.amazonaws.com/seoul_tree/seoul_tree.txt'
df = pd.read_table(url , header = 1)
df
# Out:
#       기간      자치구    노선수       수량     은행나무  ...    무궁화    소나무   목련    이팝나무      기타
# 0   2019      서울시  1,412  307,351  108,050  ...  2,374  4,539  378  20,088  20,112
# 1   2019      종로구     70    7,329    4,072  ...      -    239    -     711      29
# 2   2019       중구     48    8,250    3,640  ...     46  2,162    -     470     817
# 3   2019      용산구     39    7,835    4,444  ...      -     51  126     198     780
# 4   2019      성동구     38    8,120    1,090  ...      -     53    -     709     646
# 5   2019      광진구     28    7,223    1,247  ...      -     20  113     760     443
# 6   2019     동대문구     43   10,664    3,749  ...      1      -    -   1,176     456
# 7   2019      중랑구     57    8,365    2,774  ...    212     64    -     449   1,156
# 8   2019      성북구     78    8,449    2,722  ...      5     97    -     853     547
# 9   2019      강북구     31    7,789    3,510  ...      -  1,007    -     575     410
# 10  2019      도봉구     63    9,572    4,914  ...    214     15    -      47   1,070
# 11  2019      노원구     50   14,489    6,505  ...    150     32    1     142   1,135
# 12  2019      은평구     35    9,880    4,324  ...      3      -    -     443     582
# 13  2019     서대문구     39    8,627    3,474  ...     70      -    -     493   1,120
# 14  2019      마포구     92   14,538    3,353  ...      -    124   93   1,280     348
# 15  2019      양천구     69   13,501    5,622  ...    197      -    -     784     595
# 16  2019      강서구     55   13,719    3,977  ...     59    282    -   1,426     568
# 17  2019      구로구     81   11,548    3,594  ...      -     30   26   1,082   1,210
# 18  2019      금천구     30    6,603    3,545  ...      -      5    -     184      69
# 19  2019     영등포구    114   18,220    5,879  ...      -     40   19   1,281     651
# 20  2019      동작구     29    7,083    2,178  ...    206      7    -     397     794
# 21  2019      관악구     32   10,154    2,280  ...  1,120     59    -     249   1,194
# 22  2019      서초구     56   16,548    3,800  ...     91      -    -     446   1,143
# 23  2019      강남구     60   23,349    7,210  ...      -      -    -     768     913
# 24  2019      송파구     99   22,858   11,894  ...      -    215    -   1,651     450
# 25  2019      강동구     66   17,152    5,474  ...      -      -    -     642   1,969
# 26  2019  공원녹지사업소      1      236      179  ...      -      -    -       4       -
# 27  2019   시설관리공단      9   15,250    2,600  ...      -     37    -   2,868   1,017
#
# [28 rows x 24 columns]

# %% [markdown]
# ### "서울시에는 구별로 평균 약 400 그루 정도의 `이팝나무`가 있다"라는 가설에 대해 가설검정을 시행하세요.
#
# - 단, `서울시`, `공원녹지사업소`, `시설관리공단` 부분의 데이터는 제외합니다.
# - 가설검정 결과의 pvalue 값을 `pv1`에 저장하세요. (`.pvalue` 사용)

# %%
df = df[:][:-2]
ds = df[df['자치구']=='서울시'].index
df1 = df.drop(ds)
df1
# Out:
#       기간   자치구  노선수      수량    은행나무  ...    무궁화    소나무   목련   이팝나무     기타
# 1   2019   종로구   70   7,329   4,072  ...      -    239    -    711     29
# 2   2019    중구   48   8,250   3,640  ...     46  2,162    -    470    817
# 3   2019   용산구   39   7,835   4,444  ...      -     51  126    198    780
# 4   2019   성동구   38   8,120   1,090  ...      -     53    -    709    646
# 5   2019   광진구   28   7,223   1,247  ...      -     20  113    760    443
# 6   2019  동대문구   43  10,664   3,749  ...      1      -    -  1,176    456
# 7   2019   중랑구   57   8,365   2,774  ...    212     64    -    449  1,156
# 8   2019   성북구   78   8,449   2,722  ...      5     97    -    853    547
# 9   2019   강북구   31   7,789   3,510  ...      -  1,007    -    575    410
# 10  2019   도봉구   63   9,572   4,914  ...    214     15    -     47  1,070
# 11  2019   노원구   50  14,489   6,505  ...    150     32    1    142  1,135
# 12  2019   은평구   35   9,880   4,324  ...      3      -    -    443    582
# 13  2019  서대문구   39   8,627   3,474  ...     70      -    -    493  1,120
# 14  2019   마포구   92  14,538   3,353  ...      -    124   93  1,280    348
# 15  2019   양천구   69  13,501   5,622  ...    197      -    -    784    595
# 16  2019   강서구   55  13,719   3,977  ...     59    282    -  1,426    568
# 17  2019   구로구   81  11,548   3,594  ...      -     30   26  1,082  1,210
# 18  2019   금천구   30   6,603   3,545  ...      -      5    -    184     69
# 19  2019  영등포구  114  18,220   5,879  ...      -     40   19  1,281    651
# 20  2019   동작구   29   7,083   2,178  ...    206      7    -    397    794
# 21  2019   관악구   32  10,154   2,280  ...  1,120     59    -    249  1,194
# 22  2019   서초구   56  16,548   3,800  ...     91      -    -    446  1,143
# 23  2019   강남구   60  23,349   7,210  ...      -      -    -    768    913
# 24  2019   송파구   99  22,858  11,894  ...      -    215    -  1,651    450
# 25  2019   강동구   66  17,152   5,474  ...      -      -    -    642  1,969
#
# [25 rows x 24 columns]

# %%
et = df1['이팝나무']
et = pd.to_numeric(et.str.replace(',',''))

np.mean(et)

stats.ttest_1samp(et,400)
pv1 = stats.ttest_1samp(et,400)[1]
pv1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-3b48ed6e6395> in <module>()
#       4 np.mean(et)
#       5
# ----> 6 stats.ttest_1samp(et,400)
#       7 pv1 = stats.ttest_1samp(et,400)[1]
#       8 pv1
#
# NameError: name 'stats' is not defined

# %% [markdown]
# ### 이번에는 10개의 구를 샘플링하여, 위에 대한 가설검정을 다시 한번 시행해보세요.
#
# - 단, 아래의 코드를 참조하여 sample을 위한 seed 는 123로 설정하세요.
# - 가설검정 결과의 pvalue값을 `pv2`에 저장하세요

# %%
import numpy as np
np.random.seed(123)

rt = np.random.choice(et, size = 10)

np.mean(rt)

stats.ttest_1samp(rt,400)
pv2 = stats.ttest_1samp(rt,400)[1]
pv2
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-c42403e8137d> in <module>()
#       2 np.random.seed(123)
#       3
# ----> 4 rt = np.random.choice(et, size = 10)
#       5
#       6 np.mean(rt)
#
# NameError: name 'et' is not defined

# %% [markdown]
# ## 2. Two-Sample T-test 연습

# %% [markdown]
# ### "서울시의 구별 평균 느티나무수와 왕벚나무의 수는 차이가 없다"라는 가설에 대해 가설검정을 시행하세요.
#
# - 단, `서울시`, `공원녹지사업소`, `시설관리공단` 부분의 데이터는 제외합니다.
# - 가설검정 결과의 pvalue를 `pv3`에 저장하세요

# %%
a = df1['느티나무']
b = df1['왕벚나무']

a = pd.to_numeric(a.str.replace(',',''))
b = pd.to_numeric(b.str.replace(',',''))

np.mean(a), np.mean(b)

pv3 =stats.ttest_ind(a,b)[1]
pv3
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-02f08569a112> in <module>()
# ----> 1 a = df1['느티나무']
#       2 b = df1['왕벚나무']
#       3
#       4 a = pd.to_numeric(a.str.replace(',',''))
#       5 b = pd.to_numeric(b.str.replace(',',''))
#
# NameError: name 'df1' is not defined

# %% [markdown]
# ### Two-Sample One-tailed test를 사용하여 **평균 느티나무수가 왕벚나무 수보다 크다**라는 가설에 대한 가설검정을 시행하세요.
# - 해당 가설검정의 결과를 `ans`에 저장하세요.
#
# 이 때 `ans`가 가질 수 있는 값은 아래와 같습니다 :
# 1. "느티나무" ( 느티나무의 수가 통계적으로 유의하게 많은 경우 )
# 2. "왕벚나무" ( 왕벚나무의 수가 통계적으로 유의하게 많은 경우 )
# 3. "없음" (통계적으로 유의하지 않은 경우)
#
# Two-Sample One-tailed test를 scipy에서 하는 방법은 아래의 링크를 참고 하세요
# 참고 링크 : https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html

# %%
# 아래의 코드를 실행해주세요
# !pip install scipy --upgrade
# Out:
# Requirement already satisfied: scipy in /usr/local/lib/python3.7/dist-packages (1.4.1)
# Collecting scipy
#   Downloading scipy-1.7.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (28.5 MB)
#      |████████████████████████████████| 28.5 MB 50 kB/s
# Requirement already satisfied: numpy<1.23.0,>=1.16.5 in /usr/local/lib/python3.7/dist-packages (from scipy) (1.19.5)
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.4.1
#     Uninstalling scipy-1.4.1:
#       Successfully uninstalled scipy-1.4.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed scipy-1.7.1

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-47abdcb1dffd> in <module>()
# ----> 1 pv3
#
# NameError: name 'pv3' is not defined

# %% [markdown]
# ## 🔥 **도전과제**
# > 2문제 모두 하면 됩니다.

# %% [markdown]
# ### 1. Compare mean for multiple-sample
#
# 다음 링크를 참조하세요. <https://reneshbedre.github.io/blog/anova.html>
#
# 구별, 은행나무, 양버즘나무, 느티나무에 대해서 ANOVA Test를 실행하세요.
#
# 단, `서울시`, `공원녹지사업소`, `시설관리공단` 부분의 데이터는 제외합니다.

# %%
# 이 곳에 답안을 작성하시기 바랍니다

# %% [markdown]
# ### 2. Sampling
#
# - 세션 시간에 배웠던 4가지 sampling (Simple Random, Systematic, Stratified Random, Cluster) 방식을 구현해보세요.
#
# - 이를 위한 데이터는 1 부터 100을 담은 numpy array이며, Sampling 해야 하는 수는 20개 입니다.
#
# - Stratified Random Sampling을 위한 그룹을 나누는 기준은 1-10, 11-20, ... 과 같은 방식입니다.
#
# - Cluster Sampling에서 그룹을 나누는 기준은 5로 나눴을때의 나머지 값입니다. (0,1,2,3,4)

# %%
# 이 곳에 답안을 작성하시기 바랍니다
